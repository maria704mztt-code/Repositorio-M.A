# %% [markdown]
# LIBRERIA PANDAS. Es una herramienta especializada en la gestion de series y dataframes.

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %% [markdown]
# Los dataframes

# %%
pd.DataFrame(data=[(0,1,2), (1,2,3), (2,3,4), (3,4,5)])
# Out:
#    0  1  2
# 0  0  1  2
# 1  1  2  3
# 2  2  3  4
# 3  3  4  5

# %%
diccionarios ={'curso1':[10, 5, 33, 45, 25, 22 ],
               'curso2': [0, 15, 21, 30, 31, 11],
               'curso3': [15, 5, 1, 10, 42, 21],
               'curso4': [20, 35, 3, 15, 0, 0]}

# %%
pd.DataFrame(data=diccionarios)
# Out:
#    curso1  curso2  curso3  curso4
# 0      10       0      15      20
# 1       5      15       5      35
# 2      33      21       1       3
# 3      45      30      10      15
# 4      25      31      42       0
# 5      22      11      21       0

# %% [markdown]
# EJEMPLO

# %%
indice = ('enero', 'febrero','marzo', 'abril', 'mayo', 'junio')

# %%
cursos = pd.DataFrame(data=diccionarios, index=indice)

# %%
cursos['curso3']
# Out:
# enero      15
# febrero     5
# marzo       1
# abril      10
# mayo       42
# junio      21
# Name: curso3, dtype: int64

# %%
cursos [['curso3','curso4']]
# Out:
#          curso3  curso4
# enero        15      20
# febrero       5      35
# marzo         1       3
# abril        10      15
# mayo         42       0
# junio        21       0

# %%
type (cursos['curso3'])
# Out:
# pandas.core.series.Series

# %%
import numpy as np

# %%
datos_np = np.arange(1,13).reshape

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
indice = ['gerente', 'supervisor', 'vendedor', 'cajero']
personal = pd.DataFrame({'nombres':('Juan Pérez',
                                    'María Sánchez',
                                    'Jorge Vargas',
                                    'Rodrigo Martínez'),
            'fechas':(datetime(1995,12,21),
                      datetime(1989,1,13),
                      datetime(1992,9,14),
                      datetime(1993,7,8)),
            'saldo': (2500,
                      5345,
                      np.nan,
                      11323.2),
            'al corriente':(True,
                            True,
                            False,
                            True)}, index=indice)

# %%
personal.set_index('nombres')
# Out:
#                      fechas    saldo  al corriente
# nombres
# Juan Pérez       1995-12-21   2500.0          True
# María Sánchez    1989-01-13   5345.0          True
# Jorge Vargas     1992-09-14      NaN         False
# Rodrigo Martínez 1993-07-08  11323.2          True

# %%
personal.set_index('fechas')
# Out:
#                      nombres    saldo  al corriente
# fechas
# 1995-12-21        Juan Pérez   2500.0          True
# 1989-01-13     María Sánchez   5345.0          True
# 1992-09-14      Jorge Vargas      NaN         False
# 1993-07-08  Rodrigo Martínez  11323.2          True

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
datos = pd.DataFrame(np.arange(20).reshape(5, 4),
                     columns=('primero', 'segundo', 'tercero', 'cuarto'))

# %%
indice_1 = ("lunes", "martes", "miércoles")
marco_1 = pd.DataFrame({'Centro':[1520,1640,1043],
                       'Sur':[1422,1673,1534],
                      'Oriente':[1021,1073,1100]},
                       index=indice_1)

indice_2 = ("jueves", "viernes", "sábado")
marco_2 = pd.DataFrame({'Centro':[1321,1459,1875],
                       'Sur':[1622,1841,1920],
                      'Oriente':[1500,1432,1491]},
                      index=indice_2)
